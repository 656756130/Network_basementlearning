# %%
import numpy
import matplotlib

# %%
import networkx

# %%
import keras

# %%
import scipy

# %%
import random

# %%
from collections import deque

# %%
import torch
print(torch.__version__)  #注意是双下划线
print(torch.version.cuda)
print(torch.cuda.is_available())
print(torch.cuda.get_device_name())
# Out:
# 1.13.0+cu117
# 11.7
# True
# NVIDIA GeForce RTX 3070 Ti Laptop GPU

# %%
import HIT_networkpackage.free_network.random_networks as rn
G = rn.empty_network(10)
G = rn.create_random_networks(G,10)

# %%
import HIT_networkpackage.free_network.draw_networks as dn
dn.draw_random_layout_networks(G,20,20,True,10)

# %%
import HIT_networkpackage.free_network.distribution_of_degree as dd
k,p_k = dd.DD(G)
dn.draw_DD(k,p_k,xlim1=0,xlim2=3)
# Out:
# [(0, 3), (1, 3), (2, 5), (3, 1), (4, 6), (5, 4), (6, 3), (7, 2), (8, 1), (9, 2)]

# %%
import HIT_network.draw_networks as hn

# %%
import HIT_network as hn

# %%
import network.random_networks as rn
G = rn.empty_network(300)
GG = rn.create_random_networks1(G,300,0.99)
# Out:
# 100%|██████████| 300/300 [00:00<00:00, 33649.55it/s]

# %%
import network.Draw_networks as dn
dn.draw_random_layout_networks(GG,10,10,node_size=200)

# %%
import HIT_network.random_networks as rn
A = rn.empty_network(300)
B = rn.create_random_networks(A,300,0.95)
# Out:
# 0.9812642730078277
# 0.9768183531684735
# 0.971594847086284
# 0.9980499912266833
# 0.9793657547010496
# 0.9880852764668258
# 0.987525789313689
# 0.95184924782976
# 0.9794071303611771
# 0.9573580315699922
# 0.9746118508842124
# 0.9647928871852086
# 0.991000400360362
# 0.9573611506047477
# 0.9702320614464439
# 0.9723119895373294
# 0.968701479069961
# 0.9514061344084891
# 0.9865606131559339
# 0.9715934018625815
# 0.9656651692163413
# 0.9904023863238883
# 0.9696220715754095
# 0.9606955348124473
# 0.9813134485904021
# 0.984732447918491
# 0.9572253080712833
# 0.965973291007108
# 0.9935836163880427
# 0.976210451337843
# 0.9623879755698012
# 0.9908177958305229
# 0.9983648402216647
# 0.9693780312781606
# 0.9561066807413066
# 0.9906968003412266
# 0.9528665518371008
# 0.9766632898275003
# 0.9715203031183253
# 0.9511293638258668
# 0.9880872069421887
# 0.992807107545227
# 0.9682119533217078
# 0.9521946737625127
# 0.9655637518083345
# 0.9986652521179267
# 0.977556276695929
# 0.9603600458769225
# ...

# %%
import HIT_network.draw_networks as dn
dn.draw_random_layout_networks(B,10,10)

# %%
for i in range(0,10):
    continue
    print(i)
