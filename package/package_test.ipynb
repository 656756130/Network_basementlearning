# %%
import random_networks as rn

# %%
G = rn.empty_network(10)
print(G)
# Out:
# Graph with 10 nodes and 0 edges

# %%
rn.create_random_networks(G=G,nodes_number=10)

# %%
import matplotlib.pyplot as plt
pos = rn.nx.circular_layout(G)
options = {
    "with_labels": True,
    "font_size": 10,
    "font_weight": "bold",
    "font_color": "white",
    "node_size": 500,
    "width": 2
}
rn.nx.draw_networkx(G, pos, **options)
ax = plt.gca()
ax.margins(0.20)
plt.axis("off")
plt.show()

# %%
import Draw_networks as dn
dn.draw_random_layout_networks(G=G,figsize1=30,figsize2=30,with_labels=True,font_size=10,node_size=500,line_width=2,color="green")

# %%
import Distribution_of_Degree as dd

# %%
k,p_k = dd.DD(G=G)
print(k,p_k)
# Out:
# [(0, 3), (1, 4), (2, 2), (3, 3), (4, 1), (5, 1), (6, 5), (7, 1), (8, 1), (9, 3)]
# [0.  0.4 0.1 0.3 0.1 0.1] [0 1 2 3 4 5]
