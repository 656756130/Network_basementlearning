# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
BA = nx.random_graphs.barabasi_albert_graph(100,10)    #节点数 新生成的点与现有的点的边数
pos = nx.spring_layout(BA)
nx.draw(BA, pos, with_labels = False, node_size = 30)
plt.show()

# %%
import Draw_networks as dn
import Scale_of_network as sn
y,x = sn.distribution_of_degree(BA)
dn.log_graph_with_zero(x,y)
dn.log_graph_without_zero(x,y)
# Out:
# [(0, 45), (1, 15), (2, 32), (3, 14), (4, 29), (5, 35), (6, 18), (7, 10), (8, 1), (9, 21), (10, 14), (11, 47), (12, 55), (13, 43), (14, 30), (15, 31), (16, 46), (17, 34), (18, 41), (19, 25), (20, 27), (21, 19), (22, 17), (23, 34), (24, 36), (25, 27), (26, 32), (27, 22), (28, 19), (29, 24), (30, 20), (31, 27), (32, 19), (33, 21), (34, 19), (35, 13), (36, 16), (37, 17), (38, 21), (39, 15), (40, 27), (41, 15), (42, 16), (43, 16), (44, 11), (45, 19), (46, 17), (47, 25), (48, 16), (49, 17), (50, 17), (51, 17), (52, 11), (53, 10), (54, 14), (55, 11), (56, 13), (57, 16), (58, 11), (59, 14), (60, 15), (61, 12), (62, 12), (63, 16), (64, 13), (65, 16), (66, 16), (67, 12), (68, 11), (69, 12), (70, 13), (71, 11), (72, 13), (73, 10), (74, 12), (75, 10), (76, 10), (77, 11), (78, 12), (79, 10), (80, 11), (81, 10), (82, 11), (83, 11), (84, 11), (85, 11), (86, 11), (87, 10), (88, 10), (89, 10), (90, 11), (91, 12), (92, 10), (93, 10), (94, 10), (95, 10), (96, 10), (97, 10), (98, 10), (99, 10)]

# %%
print(sn.NDNW_average_degree(BA))
# Out:
# 18.0
